# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Titanic Dataset.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1, 0, 3, ..., 7.25, nan, 'S'],
#        [2, 1, 1, ..., 71.2833, 'C85', 'C'],
#        [3, 1, 3, ..., 7.925, nan, 'S'],
#        ...,
#        [889, 0, 3, ..., 23.45, nan, 'S'],
#        [890, 1, 1, ..., 30.0, 'C148', 'C'],
#        [891, 0, 3, ..., 7.75, nan, 'Q']], dtype=object)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
df.fillna(np.mean).isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
df.value_counts()
# Out:
# PassengerId  Survived  Pclass  Name                                             Sex     Age    SibSp  Parch  Ticket       Fare      Embarked
# 1            0         3       Braund, Mr. Owen Harris                          male    22.00  1      0      A/5 21171    7.2500    S           1
# 622          1         1       Kimball, Mr. Edwin Nelson Jr                     male    42.00  1      0      11753        52.5542   S           1
# 595          0         2       Chapman, Mr. John Henry                          male    37.00  1      0      SC/AH 29037  26.0000   S           1
# 596          0         3       Van Impe, Mr. Jean Baptiste                      male    36.00  1      1      345773       24.1500   S           1
# 598          0         3       Johnson, Mr. Alfred                              male    49.00  0      0      LINE         0.0000    S           1
# ...

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
df=df.dropna()

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.fillna(np.mean).isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
df['Sex'].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
dir(df)
# Out:
# ['Age',
#  'Cabin',
#  'Embarked',
#  'Fare',
#  'Name',
#  'Parch',
#  'PassengerId',
#  'Pclass',
#  'Sex',
#  'SibSp',
#  'Survived',
#  'T',
#  'Ticket',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
df['Survived'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df['Sex'].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Sex'>

# %%
import seaborn as sns 
sns.barplot(data=df,x=df["Survived"],y=df['Survived'].value_counts(),hue=df['Sex']);

# %%
sns.displot(data=df,x=df["Age"],hue=df["Pclass"]);

# %%
df.var()
# Out:
# C:\Users\SAP\AppData\Local\Temp\ipykernel_7300\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# PassengerId    66231.000000
# Survived           0.236772
# Pclass             0.699015
# Age              211.019125
# SibSp              1.216043
# Parch              0.649728
# Fare            2469.436846
# dtype: float64

# %%
sns.heatmap(df.corr(),annot=True);

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
sns.scatterplot(data=df,x="Survived",y="Pclass",hue="Sex");

# %%
sns.scatterplot(data=df,x="Survived",y="Pclass");

# %%
df["Age"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df[df["Age"]<18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 9             10         1       2      Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3          Sandstrom, Miss. Marguerite Rut
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# ..           ...       ...     ...                                      ...
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
# 853          854         1       1                Lines, Miss. Mary Conover
# 869          870         1       3          Johnson, Master. Harold Theodor
# 875          876         1       3         Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.scatterplot(data=df,x="Survived",y="Age");

# %%
sns.scatterplot(data=df,x="Survived",y="Age",hue="Sex");

# %%
df.groupby(df["Survived"])["Sex"].count()
# Out:
# Survived
# 0    549
# 1    342
# Name: Sex, dtype: int64

# %%
a=df.pivot_table(values='PassengerId',index="Survived",columns="Sex",aggfunc='count')
a
# Out:
# Sex       female  male
# Survived
# 0             81   468
# 1            233   109

# %%
a.plot(kind="bar");

# %%
c=df.groupby(by=["Survived","Sex"])["Age"].count()
c
# Out:
# Survived  Sex
# 0         female     64
#           male      360
# 1         female    197
#           male       93
# Name: Age, dtype: int64

# %%
c.plot(kind="bar",color=['red','g','black','b']);

# %%
b=df.pivot_table(values='Pclass',index="Survived",columns="Embarked",aggfunc='count')
b
# Out:
# Embarked   C   Q    S
# Survived
# 0         75  47  427
# 1         93  30  217

# %%
b.plot(kind="bar");

# %%
import  pandas as pd

# %%
a={"Id":[1,2,3,4],
   "Name":["yug","moksh","chintan","kunj"],
   "City":["dharti","swarg","pruthvi","pacific"]}
df1=pd.DataFrame(a)

# %%
df1
# Out:
#    Id     Name     City
# 0   1      yug   dharti
# 1   2    moksh    swarg
# 2   3  chintan  pruthvi
# 3   4     kunj  pacific

# %%
df1["Age"]=[10,30,23,18]
df1
# Out:
#    Id     Name     City  Age
# 0   1      yug   dharti   10
# 1   2    moksh    swarg   30
# 2   3  chintan  pruthvi   23
# 3   4     kunj  pacific   18

# %%
b={"Id":[1,2,3,4,5],
   "Name":["yug","moksh","chintan","kunj","bhavin"],
   "City":["dharti","swarg","pruthvi","pacific","dubai"],
  "Age":[10,30,23,18,31],
  "Weight":[50,20,40,100,32]}
df=pd.DataFrame(b)

# %%
df
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10      50
# 1   2    moksh    swarg   30      20
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100
# 4   5   bhavin    dubai   31      32

# %%
pd.concat([df1,df])
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10     NaN
# 1   2    moksh    swarg   30     NaN
# 2   3  chintan  pruthvi   23     NaN
# 3   4     kunj  pacific   18     NaN
# 0   1      yug   dharti   10    50.0
# 1   2    moksh    swarg   30    20.0
# 2   3  chintan  pruthvi   23    40.0
# 3   4     kunj  pacific   18   100.0
# 4   5   bhavin    dubai   31    32.0

# %%
df.merge(df1)
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10      50
# 1   2    moksh    swarg   30      20
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100

# %%
df.merge(df1,how="outer")
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10      50
# 1   2    moksh    swarg   30      20
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100
# 4   5   bhavin    dubai   31      32

# %%
df.merge(df1,how="right")
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10      50
# 1   2    moksh    swarg   30      20
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100

# %%
df.merge(df1,how="inner")
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10      50
# 1   2    moksh    swarg   30      20
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100

# %%
df.merge(df1,how="left")
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10      50
# 1   2    moksh    swarg   30      20
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100
# 4   5   bhavin    dubai   31      32

# %%
df.merge(df1,how="inner").sort_index(ignore_index=True)
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10      50
# 1   2    moksh    swarg   30      20
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100

# %%
df2=df.merge(df1,how="inner").sort_index(ignore_index=True)

# %%
df2.sort_values('Name')
# Out:
#    Id     Name     City  Age  Weight
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100
# 1   2    moksh    swarg   30      20
# 0   1      yug   dharti   10      50

# %%
a=lambda x:x**2

# %%
a(2)
# Out:
# 4

# %%
a=lambda x:x**0.5

# %%
a(4)
# Out:
# 2.0

# %%
a(1024)
# Out:
# 32.0

# %%
df2['Weight'].apply(lambda x:x**2)
# Out:
# 0     2500
# 1      400
# 2     1600
# 3    10000
# Name: Weight, dtype: int64

# %%
df.merge(df2)
# Out:
#    Id     Name     City  Age  Weight
# 0   1      yug   dharti   10      50
# 1   2    moksh    swarg   30      20
# 2   3  chintan  pruthvi   23      40
# 3   4     kunj  pacific   18     100

# %%
df1["Lambda"]=df2['Weight'].apply(lambda x:x**2)

# %%
df1
# Out:
#    Id     Name     City  Age  Lambda
# 0   1      yug   dharti   10    2500
# 1   2    moksh    swarg   30     400
# 2   3  chintan  pruthvi   23    1600
# 3   4     kunj  pacific   18   10000

# %%
new=df.loc[:50]

# %%
new
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
df["Age"].unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df["Fare"].unique()
# Out:
# array([  7.25  ,  71.2833,   7.925 ,  53.1   ,   8.05  ,   8.4583,
#         51.8625,  21.075 ,  11.1333,  30.0708,  16.7   ,  26.55  ,
#         31.275 ,   7.8542,  16.    ,  29.125 ,  13.    ,  18.    ,
#          7.225 ,  26.    ,   8.0292,  35.5   ,  31.3875, 263.    ,
#          7.8792,   7.8958,  27.7208, 146.5208,   7.75  ,  10.5   ,
#         82.1708,  52.    ,   7.2292,  11.2417,   9.475 ,  21.    ,
#         41.5792,  15.5   ,  21.6792,  17.8   ,  39.6875,   7.8   ,
#         76.7292,  61.9792,  27.75  ,  46.9   ,  80.    ,  83.475 ,
#         27.9   ,  15.2458,   8.1583,   8.6625,  73.5   ,  14.4542,
#         56.4958,   7.65  ,  29.    ,  12.475 ,   9.    ,   9.5   ,
#          7.7875,  47.1   ,  15.85  ,  34.375 ,  61.175 ,  20.575 ,
#         34.6542,  63.3583,  23.    ,  77.2875,   8.6542,   7.775 ,
#         24.15  ,   9.825 ,  14.4583, 247.5208,   7.1417,  22.3583,
#          6.975 ,   7.05  ,  14.5   ,  15.0458,  26.2833,   9.2167,
# ...
